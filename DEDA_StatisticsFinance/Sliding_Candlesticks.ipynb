# %%
#to install modules or packages use !pip install "x" or %pip install "x" or pip install "x" in terminal
from datetime import datetime, timedelta
import yfinance as yf
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.offline as py
import os

CURRENCY = 'EUR'

file_name = 'btc_data_U5.csv'

btc_data = pd.read_csv(file_name, sep=',')

# You can also get the data from Yahoo Finance. You first have to comment out the
# CSV version and remove the comments (""") from these lines below
"""
def get_crypto_data(symbol: str, currency: str = CURRENCY) -> pd.DataFrame:
    # Fixed start date
    start_date = "2017-01-01"
    # End date = today
    end_date = datetime.now().strftime('%Y-%m-%d')

    data = yf.download(
        tickers=f'{symbol}-{currency}',
        start=start_date,
        end=end_date,
        interval='1d'
    )
    
    return data

btc_data = get_crypto_data("BTC")
"""

# Flatten multi-index columns if present (though CSV shouldn't have multi-index)
if isinstance(btc_data.columns, pd.MultiIndex):
    btc_data.columns = btc_data.columns.get_level_values(0)

# Create candlestick chart
fig = go.Figure(data=[
    go.Candlestick(
        x=btc_data['Date'],
        close=btc_data['Close'],
        high=btc_data['High'],
        low=btc_data['Low'],
        open=btc_data['Open']
    )
])

fig.update_yaxes(tickprefix=CURRENCY)
fig.show()
