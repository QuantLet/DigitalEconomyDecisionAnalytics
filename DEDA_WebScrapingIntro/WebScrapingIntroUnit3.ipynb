# %% [markdown]
# # **DEDA Unit 3:** Introduction of Web Scraping in Python

# %% [markdown]
# #### **Reading XML Data Online**

# %%
"""
DEDA Unit 3
Introduction of Web Scraping in Python
Authors: WK Härdle Xiaorui ZUO
Date: 20240904
"""


"""
Reading XML Data Online
"""
"""
We use json module to unpack data from webpage. 
"""
import requests
import xml.dom.minidom
response = requests.get("https://home.treasury.gov/sites/default/files/interest-rates/daily_treas_bill_rates.xml")
content = response.content
"""
Now let us have a look at this web page content  
"""
print(content)

"""
One more time, this time on a google site  
"""
dataDOM = xml.dom.minidom.parseString(content)
response = requests.get("https://news.google.com/news/rss/headlines/section/q/finance%20news/finance%20news?ned=us&hl=en")
content = response.content

print(content)
# Out:
# b'<QR_KI_BILLCLIFF><LIST_G_CS_4WK_CLOSE_AVG><G_CS_4WK_CLOSE_AVG><LIST_G_INDEX_DATE><G_INDEX_DATE><INDEX_DATE>02-SEP-24</INDEX_DATE><ROUND_B1_CLOSE_4WK_2></ROUND_B1_CLOSE_4WK_2><ROUND_B1_YIELD_4WK_2></ROUND_B1_YIELD_4WK_2><ROUND_B1_CLOSE_8WK_2></ROUND_B1_CLOSE_8WK_2><ROUND_B1_YIELD_8WK_2></ROUND_B1_YIELD_8WK_2><ROUND_B1_CLOSE_13WK_2></ROUND_B1_CLOSE_13WK_2><ROUND_B1_YIELD_13WK_2></ROUND_B1_YIELD_13WK_2><ROUND_B1_CLOSE_17WK_2></ROUND_B1_CLOSE_17WK_2><ROUND_B1_YIELD_17WK_2></ROUND_B1_YIELD_17WK_2><ROUND_B1_CLOSE_26WK_2></ROUND_B1_CLOSE_26WK_2><ROUND_B1_YIELD_26WK_2></ROUND_B1_YIELD_26WK_2><ROUND_B1_CLOSE_52WK_2></ROUND_B1_CLOSE_52WK_2><ROUND_B1_YIELD_52WK_2></ROUND_B1_YIELD_52WK_2><BOND_MKT_UNAVAIL_REASON>FEDERAL HOLIDAY</BOND_MKT_UNAVAIL_REASON><MATURITY_DATE_4WK></MATURITY_DATE_4WK><MATURITY_DATE_8WK></MATURITY_DATE_8WK><MATURITY_DATE_13WK></MATURITY_DATE_13WK><MATURITY_DATE_17WK></MATURITY_DATE_17WK><MATURITY_DATE_26WK></MATURITY_DATE_26WK><MATURITY_DATE_52WK></MATURITY_DATE_52WK><CUSIP_4WK></CUSIP_4WK><CUSIP_8WK></CUSIP_8WK><CUSIP_13WK></CUSIP_13WK><CUSIP_17WK></CUSIP_17WK><CUSIP_26WK></CUSIP_26WK><CUSIP_52WK></CUSIP_52WK><QUOTE_DATE>02-SEP-24</QUOTE_DATE><CF_NEW_DATE>09/02/2024 MARKET CLOSED</CF_NEW_DATE></G_INDEX_DATE><G_INDEX_DATE><INDEX_DATE>03-SEP-24</INDEX_DATE><ROUND_B1_CLOSE_4WK_2>5.16</ROUND_B1_CLOSE_4WK_2><ROUND_B1_YIELD_4WK_2>5.25</ROUND_B1_YIELD_4WK_2><ROUND_B1_CLOSE_8WK_2>5.1</ROUND_B1_CLOSE_8WK_2><ROUND_B1_YIELD_8WK_2>5.21</ROUND_B1_YIELD_8WK_2><ROUND_B1_CLOSE_13WK_2>4.97</ROUND_B1_CLOSE_13WK_2><ROUND_B1_YIELD_13WK_2>5.1</ROUND_B1_YIELD_13WK_2><ROUND_B1_CLOSE_17WK_2>4.88</ROUND_B1_CLOSE_17WK_2><ROUND_B1_YIELD_17WK_2>5.03</ROUND_B1_YIELD_17WK_2><ROUND_B1_CLOSE_26WK_2>4.65</ROUND_B1_CLOSE_26WK_2><ROUND_B1_YIELD_26WK_2>4.83</ROUND_B1_YIELD_26WK_2><ROUND_B1_CLOSE_52WK_2>4.15</ROUND_B1_CLOSE_52WK_2><ROUND_B1_YIELD_52WK_2>4.34</ROUND_B1_YIELD_52WK_2><BOND_MKT_UNAVAIL_REASON></BOND_MKT_UNAVAIL_REASON><MATURITY_DATE_4WK>01-OCT-24</MATURITY_DATE_4WK><MATURITY_DATE_8WK>29-OCT-24</MATURITY_DATE_8WK><MATURITY_DATE_13WK>05-DEC-24</MATURITY_DATE_13WK><MATURITY_DATE_17WK>31-DEC-24</MATURITY_DATE_17WK><MATURITY_DATE_26WK>06-MAR-25</MATURITY_DATE_26WK><MATURITY_DATE_52WK>04-SEP-25</MATURITY_DATE_52WK><CUSIP_4WK>912797LK1</CUSIP_4WK><CUSIP_8WK>912797LV7</CUSIP_8WK><CUSIP_13WK>912797LF2</CUSIP_13WK><CUSIP_17WK>912797MR5</CUSIP_17WK><CUSIP_26WK>912797MM6</CUSIP_26WK><CUSIP_52WK>912797MH7</CUSIP_52WK><QUOTE_DATE>03-SEP-24</QUOTE_DATE><CF_NEW_DATE>09/03/2024</CF_NEW_DATE></G_INDEX_DATE></LIST_G_INDEX_DATE><CS_4WK_CLOSE_AVG>5.16</CS_4WK_CLOSE_AVG><CS_4WK_YIELD_AVG>5.25</CS_4WK_YIELD_AVG><CS_8WK_CLOSE_AVG>5.1</CS_8WK_CLOSE_AVG><CS_8WK_YIELD_AVG>5.21</CS_8WK_YIELD_AVG><CS_13WK_CLOSE_AVG>4.97</CS_13WK_CLOSE_AVG><CS_13WK_YIELD_AVG>5.1</CS_13WK_YIELD_AVG><CS_17WK_CLOSE_AVG>4.88</CS_17WK_CLOSE_AVG><CS_17WK_YIELD_AVG>5.03</CS_17WK_YIELD_AVG><CS_26WK_CLOSE_AVG>4.65</CS_26WK_CLOSE_AVG><CS_26WK_YIELD_AVG>4.83</CS_26WK_YIELD_AVG><CS_52WK_CLOSE_AVG>4.15</CS_52WK_CLOSE_AVG><CS_52WK_YIELD_AVG>4.34</CS_52WK_YIELD_AVG><CF_WEEK>202436</CF_WEEK></G_CS_4WK_CLOSE_AVG></LIST_G_CS_4WK_CLOSE_AVG></QR_KI_BILLCLIFF>'
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><rss version="2.0" xmlns:media="http://search.yahoo.com/mrss/"><channel><generator>NFE/5.0</generator><title>"finance news" - Google News</title><link>https://news.google.com/search?hl=en-US&amp;q=finance+news&amp;gl=US&amp;ceid=US:en</link><language>en-US</language><webMaster>news-webmaster@google.com</webMaster><copyright>2024 Google Inc.</copyright><lastBuildDate>Wed, 04 Sep 2024 04:50:18 GMT</lastBuildDate><description>Google News</description><item><title>Nvidia stock tumbles 9% to lowest level since mid-August - Yahoo Finance</title><link>https://news.google.com/rss/articles/CBMiowFBVV95cUxNYjlGU0o4c0JkWU4ya0FQZXNlMloxRDZzT29MTkYxTGFtUnh
lt;/a&gt;&amp;nbsp;&amp;nbsp;&lt;font color="#6f6f6f" ...

# %% [markdown]
# #### **Reading JSON Data Online**

# %%
"""
We use json module to unpack US GOV data and receive the number of US passport applications each fiscal year from https://cadatacatalog.state.gov/dataset .
"""

import requests
import json
import pandas as pd

url = 'https://cadatacatalog.state.gov/dataset/a765ec3a-cf98-4722-a562-40c3f03d24d5/resource/a3bb04a8-dcda-4a03-ba87-e4ec63f2c4c3/download/passportapplicationbyfiscalyear.json'

response = requests.get(url)
content = json.loads(response.content)
Year = [item['Year'] for item in content]
Count = [item['Count'] for item in content]

Info = zip(Year, Count)
PassportData = pd.DataFrame(list(Info), columns=['Year', 'Count'])
print(PassportData)
# Out:
#     Year     Count
# 0   2012  12481013
# 1   2011  12028710
# 2   2010  14005102
# 3   2009  14045147
# 4   2008  16054336
# 5   2007  18581977
# 6   2006  12333428
# 7   2005  10412146
# 8   2004   9046790
# 9   2003   7355537
# 10  2002   7217320
# 11  2001   7182304
# 12  2000   7367472
# 13  1999   6801129
# 14  1998   6557987
# 15  1997   6330968
# 16  1996   5531268
# 17  1995   5242488
# 18  1994   4748763
# 19  1993   3912154
# 20  1992   3479946
# 21  1991   3124527
# 22  1990   3704833
# 23  1989   3663323
# 24  1988   4206472
# 25  1987   4794993
# 26  1986   4114532

# %% [markdown]
# #### **Webpage with RSS Feed**

# %%
"""
Retrieving the titles from the Financial Times Website (https://www.ft.com/?edition=international) 
"""
# !pip install feedparser
import feedparser
news = feedparser.parse("https://www.ft.com/?edition=international&format=rss")

for index, item in enumerate(news.entries): # list all titles
    print("{0}.{1}".format(index, item["title"]))
# Out:
# Requirement already satisfied: feedparser in /Users/haerdle/anaconda3/lib/python3.11/site-packages (6.0.10)
# Requirement already satisfied: sgmllib3k in /Users/haerdle/anaconda3/lib/python3.11/site-packages (from feedparser) (1.0.0)
# 0.Russia built covert trade channel with India, leaks reveal
# 1.US threatens sanctions against countries hosting Russian banks
# 2.US warns Turkey of ‘consequences’ over military-linked exports to Russia
# 3.How national security has transformed economic policy
# 4.The Fed needs to avoid becoming passive aggressive
# 5.Index rejects find favour with stock market bargain hunters
# 6.Australian economic growth slows as exports and consumption weaken
# 7.Nvidia leads US market sell-off as weak data feeds slowdown fears
# 8.Is Jay Powell lucky or good?
# 9.Ukraine undertakes biggest government ‘reboot’ of war
# 10.Ukraine energy chief ousted in ‘politically motivated’ move
# 11.US homebuilders face credit crunch as banks cut lending
# 12.Erdoğan’s rhetoric stokes anti-Israel sentiment in Turkey
# 13.Sony chief bets on original content as part of ‘creation shift’
# 14.Nippon Steel pledges US Steel would be run by Americans
# 15.Harris makes small business pitch with boost to start-up tax relief
# 16.Goldman slashes copper forecast dimming miners’ profit outlook
# 17.Former aide to NY governor charged with acting as an agent of China
# 18.China to launch anti-dumping probe into Canadian canola exports
# 19.Ugandan opposition leader Bobi Wine shot
# 20.Taliban’s closer ties with UAE signal global divide over Afghan regime
# 21.Mexico’s top court joins strike as ruling party weighs contentious reform
# 22.Business concerns intensify over Mexico’s constitutional shake-up
# 23.Netanyahu attacks UK decision on arms to Israel as ‘shameful’
# 24.Netanyahu doubles down on Gaza strategy as he seeks to ride out latest storm
# 25.EU urged to overhaul €387bn farm subsidies regime
# 26.Europe’s failure to keep pace on corporate bonds is baked in
# 27.UK regulator to slash maximum fraud losses banks are forced to cover
# 28.Insurers face $151bn in yearly losses from natural disasters, report forecasts
